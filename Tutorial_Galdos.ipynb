# %%
def print_10_nums():
    for i in range(10):
        print i,

# %%
con = sqlite3.connect("../data/test_db.sqlite")
df = pd.read_sql("SELECT * from weather_2012 ORDER BY Weather LIMIT 3", con)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b768fe785da1> in <module>()
# ----> 1 con = sqlite3.connect("../data/test_db.sqlite")
#       2 df = pd.read_sql("SELECT * from weather_2012 ORDER BY Weather LIMIT 3", con)
#       3 df
#
# NameError: name 'sqlite3' is not defined

# %%
weather_df = pd.read_csv('../data/weather_2012.csv')
con = sqlite3.connect("../data/test_db.sqlite")
con.execute("DROP TABLE IF EXISTS weather_2012")
pd.io.sql.write_frame(weather_df, "weather_2012", con)
# Out:
# c:\Users\marcelo.galdos\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\sql.py:1234: FutureWarning: write_frame is deprecated, use to_sql
#   warnings.warn("write_frame is deprecated, use to_sql", FutureWarning)
# c:\Users\marcelo.galdos\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\sql.py:963: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   warnings.warn(_SAFE_NAMES_WARNING)

# %%
con = sqlite3.connect("../data/test_db.sqlite")
df = pd.read_sql(')

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 3)

# %%
bikes = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
#bikes['Berri 1'].plot()
berri_bikes = bikes[['Berri 1']]
berri_bikes[:5]
# Out:
#             Berri 1
# Date
# 2012-01-01       35
# 2012-01-02       83
# 2012-01-03      135
# 2012-01-04      144
# 2012-01-05      197

# %%
berri_bikes['weekday'] = berri_bikes.index.weekday
berri_bikes[:10]
# Out:
#             Berri 1  weekday  day
# Date
# 2012-01-01       35        6    1
# 2012-01-02       83        0    2
# 2012-01-03      135        1    3
# 2012-01-04      144        2    4
# 2012-01-05      197        3    5
# 2012-01-06      146        4    6
# 2012-01-07       98        5    7
# 2012-01-08       95        6    8
# 2012-01-09      244        0    9
# 2012-01-10      397        1   10

# %%
weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts.plot(kind='bar')

# %%
bikes = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
berri_bikes = bikes[['Berri 1']]
berri_bikes['weekday'] = berri_bikes.index.weekday
weekday_counts = berri_bikes.groupby('weekday').aggregate(sum)
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts.plot(kind='bar')

# %%
bikes
bikes['weekday'] = bikes.index.weekday
weekday_counts = bikes.groupby('weekday').aggregate(sum)
weekday_counts.index = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekday_counts.plot(kind='bar')

# %%
fixed_df = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
fixed_df[:3]
# Out:
#             Berri 1  Brébeuf (données non disponibles)  Côte-Sainte-Catherine  \
# Date
# 2012-01-01       35                                NaN                      0
# 2012-01-02       83                                NaN                      1
# 2012-01-03      135                                NaN                      2
#
#             Maisonneuve 1  Maisonneuve 2  du Parc  Pierre-Dupuy  Rachel1  \
# Date
# 2012-01-01             38             51       26            10       16
# 2012-01-02             68            153       53             6       43
# 2012-01-03            104            248       89             3       58
#
#             St-Urbain (données non disponibles)
# Date
# 2012-01-01                                  NaN
# 2012-01-02                                  NaN
# 2012-01-03                                  NaN

# %%
raw_gef = pd.read_csv('C:/temp/result_test.csv')
print raw_gef
fixed_gef = pd.read_csv('C:/temp/result_test.csv', sep=';', encoding='latin1')
fixed_gef
# Out:
#                                                                                                 polygon id;id_climate;SOTER_newsuid;chain4_id;base;chain1_id;chain2_id;chain3_id;chain4_id;chain5_id;chain6_id;chain7_id;chain8_id;somsc1920_1939int;somsc1920_1939slp;somsc1920_1939r2;somtc1920_1939int;somtc1920_1939slp;somtc1920_1939r2;totc1920_1939int
# 2095;1;10624;506;497;503;504;505;506;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;508;526;529;530;509;508;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
# 2095;1;10624;515;497;495;514;513;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;497;495;514;516;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;497;495;517;516;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;497;503;511;513;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;497;503;511;516;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;497;503;504;518;515;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2095;1;10624;515;526;519;514;513;515;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
# 2095;1;10624;515;526;531;514;516;515;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
# 2095;1;10624;515;526;531;517;516;515;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
# 2095;1;10624;536;526;529;530;509;536;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
# 2096;1;10625;506;497;503;504;505;506;0;0;0;0;6284 741;-7  939;0 16;6348  161;-0 618;0 002;6596                                                622
# 2096;1;10625;508;526;529;530;509;508;0;0;0;0;5481 579;-24 329;0 079;5459 22;-11 375;0 018;5334                                                251
#     polygon id  id_climate  SOTER_newsuid  chain4_id  base  chain1_id  \
# 0         2095           1          10624        506   497        503
# 1         2095           1          10624        508   526        529
# 2         2095           1          10624        515   497        495
# 3         2095           1          10624        515   497        495
# 4         2095           1          10624        515   497        495
# 5         2095           1          10624        515   497        503
# 6         2095           1          10624        515   497        503
# 7         2095           1          10624        515   497        503
# 8         2095           1          10624        515   526        519
# 9         2095           1          10624        515   526        531
# 10        2095           1          10624        515   526        531
# 11        2095           1          10624        536   526        529
# 12        2096           1          10625        506   497        503
# 13        2096           1          10625        508   526        529
#
#     chain2_id  chain3_id  chain4_id.1  chain5_id  chain6_id  chain7_id  \
# 0         504        505          506          0          0          0
# 1         530        509          508          0          0          0
# 2         514        513          515          0          0          0
# 3         514        516          515          0          0          0
# 4         517        516          515          0          0          0
# 5         511        513          515          0          0          0
# 6         511        516          515          0          0          0
# 7         504        518          515          0          0          0
# 8         514        513          515          0          0          0
# 9         514        516          515          0          0          0
# 10        517        516          515          0          0          0
# 11        530        509          536          0          0          0
# 12        504        505          506          0          0          0
# 13        530        509          508          0          0          0
#
#     chain8_id somsc1920_1939int somsc1920_1939slp somsc1920_1939r2  \
# 0           0          6284,741            -7,939             0,16
# 1           0          5481,579           -24,329            0,079
# 2           0          6284,741            -7,939             0,16
# 3           0          6284,741            -7,939             0,16
# 4           0          6284,741            -7,939             0,16
# 5           0          6284,741            -7,939             0,16
# 6           0          6284,741            -7,939             0,16
# 7           0          6284,741            -7,939             0,16
# 8           0          5481,579           -24,329            0,079
# 9           0          5481,579           -24,329            0,079
# 10          0          5481,579           -24,329            0,079
# 11          0          5481,579           -24,329            0,079
# 12          0          6284,741            -7,939             0,16
# 13          0          5481,579           -24,329            0,079
#
#    somtc1920_1939int somtc1920_1939slp somtc1920_1939r2 totc1920_1939int
# 0           6348,161            -0,618            0,002         6596,622
# 1            5459,22           -11,375            0,018         5334,251
# 2           6348,161            -0,618            0,002         6596,622
# 3           6348,161            -0,618            0,002         6596,622
# 4           6348,161            -0,618            0,002         6596,622
# 5           6348,161            -0,618            0,002         6596,622
# 6           6348,161            -0,618            0,002         6596,622
# 7           6348,161            -0,618            0,002         6596,622
# 8            5459,22           -11,375            0,018         5334,251
# 9            5459,22           -11,375            0,018         5334,251
# 10           5459,22           -11,375            0,018         5334,251
# 11           5459,22           -11,375            0,018         5334,251
# 12          6348,161            -0,618            0,002         6596,622
# 13           5459,22           -11,375            0,018         5334,251

# %%
fixed_df['Berri 1'].plot()

# %%
fixed_df.plot(figsize=(15, 10))

# %%
df = pd.read_csv('../data/bikes.csv', sep=';', encoding='latin1', parse_dates=['Date'], dayfirst=True, index_col='Date')
df['Berri 1'].plot()

# %%
pd.set_option('display.mpl_style', 'default')
pd.set_option('display.line_width', 5000)
pd.set_option('display.max_columns', 60)
plt.rcParams['figure,figsize'] = (15, 5)
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-f009521be167> in <module>()
#       2 pd.set_option('display.line_width', 5000)
#       3 pd.set_option('display.max_columns', 60)
# ----> 4 plt.rcParams['figure,figsize'] = (15, 5)
#
# c:\Users\marcelo.galdos\AppData\Local\Continuum\Anaconda\lib\site-packages\matplotlib\__init__.pyc in __setitem__(self, key, val)
#     792         except KeyError:
#     793             raise KeyError('%s is not a valid rc parameter.\
# --> 794 See rcParams.keys() for a list of valid parameters.' % (key,))
#     795
#     796     def __getitem__(self, key):
#
# KeyError: 'figure,figsize is not a valid rc parameter.See rcParams.keys() for a list of valid parameters.'

# %%
complaints = pd.read_csv('../data/311-service-requests.csv')
# Out:
# c:\Users\marcelo.galdos\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:1130: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
complaint_counts = complaints['Complaint Type'].value_counts()
complaint_counts[:10].plot(kind='bar')

# %%
weather_2012_final = pd.read_csv('../data/weather_2012.csv', index_col='Date/Time')
weather_2012_final['Temp (C)'].plot(figsize=(15, 6))

# %%
url_template = "http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data"

# %%
url_template
# Out:
# 'http://climate.weather.gc.ca/climateData/bulkdata_e.html?format=csv&stationID=5415&Year={year}&Month={month}&timeframe=1&submit=Download+Data'

# %%
url = url_template.format(month=3, year=2012)
weather_mar2012 = pd.read_csv(url, skiprows=16, index_col='Date/Time', parse_dates=True, encoding='latin1')
weather_mar2012[u"Temp (\xc2\xb0C)"].plot(figsize=(15, 5))

# %%
weather_mar2012.columns = [
    u'Year', u'Month', u'Day', u'Time', u'Data Quality', u'Temp (C)', 
    u'Temp Flag', u'Dew Point Temp (C)', u'Dew Point Temp Flag', 
    u'Rel Hum (%)', u'Rel Hum Flag', u'Wind Dir (10s deg)', u'Wind Dir Flag', 
    u'Wind Spd (km/h)', u'Wind Spd Flag', u'Visibility (km)', u'Visibility Flag',
    u'Stn Press (kPa)', u'Stn Press Flag', u'Hmdx', u'Hmdx Flag', u'Wind Chill', 
    u'Wind Chill Flag', u'Weather']

# %%
weather_mar2012 = weather_mar2012.drop(['Year', 'Month', 'Day', 'Time', 'Data Quality'], axis=1) 
weather_mar2012[:5]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa) Weather
# Date/Time
# 2012-03-01 00:00:00      -5.5                -9.7           72               24              4.0           100.97    Snow
# 2012-03-01 01:00:00      -5.7                -8.7           79               26              2.4           100.87    Snow
# 2012-03-01 02:00:00      -5.4                -8.3           80               28              4.8           100.80    Snow
# 2012-03-01 03:00:00      -4.7                -7.7           79               28              4.0           100.69    Snow
# 2012-03-01 04:00:00      -5.4                -7.8           83               35              1.6           100.62    Snow

# %%
temperatures = weather_mar2012[[u'Temp (C)']]
temperatures['Hour'] = weather_mar2012.index.hour
temperatures.groupby('Hour').aggregate(np.median).plot()

# %%
def download_weather_month(year, month):
    if month == 1:
        year += 1
    url = url_template.format(year=year, month=month)
    weather_data = pd.read_csv(url, skiprows=16, index_col='Date/Time', parse_dates=True)
    weather_data = weather_data.dropna(axis=1)
    weather_data.columns = [col.replace('\xb0', '') for col in weather_data.columns]
    weather_data = weather_data.drop(['Year', 'Day', 'Month', 'Time', 'Data Quality'], axis=1)
    return weather_data
download_weather_month(2012, 1)[:5]
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)       Weather
# Date/Time
# 2013-01-01 00:00:00      -1.0                -1.7           95               35              6.4            99.89          Snow
# 2013-01-01 01:00:00      -2.0                -5.1           79               35             16.1            99.93  Mainly Clear
# 2013-01-01 02:00:00      -2.7                -6.0           78               28             19.3           100.08          Snow
# 2013-01-01 03:00:00      -5.6               -11.7           62               30             25.0           100.21         Clear
# 2013-01-01 04:00:00      -7.7               -12.6           68               35             19.3           100.32  Mainly Clear

# %%
data_by_month = [download_weather_month(2012, i) for i in range(1, 13)]

# %%
weather_2012 = pd.concat(data_by_month)
weather_2012
# Out:
#                      Temp (C)  Dew Point Temp (C)  Rel Hum (%)  Wind Spd (km/h)  Visibility (km)  Stn Press (kPa)        Weather
# Date/Time
# 2013-01-01 00:00:00      -1.0                -1.7           95               35              6.4            99.89           Snow
# 2013-01-01 01:00:00      -2.0                -5.1           79               35             16.1            99.93   Mainly Clear
# 2013-01-01 02:00:00      -2.7                -6.0           78               28             19.3           100.08           Snow
# 2013-01-01 03:00:00      -5.6               -11.7           62               30             25.0           100.21          Clear
# 2013-01-01 04:00:00      -7.7               -12.6           68               35             19.3           100.32   Mainly Clear
# 2013-01-01 05:00:00      -9.7               -14.8           66               33             25.0           100.47          Clear
# 2013-01-01 06:00:00     -11.1               -17.0           62               30             25.0           100.65          Clear
# 2013-01-01 07:00:00     -12.2               -17.2           66               20             25.0           100.78          Clear
# 2013-01-01 08:00:00     -13.0               -17.7           68               13             24.1           100.87          Clear
# 2013-01-01 09:00:00     -13.0               -17.3           70               20             24.1           100.86          Clear
# 2013-01-01 10:00:00     -12.6               -17.8           65               19             24.1           100.90          Clear
# 2013-01-01 11:00:00     -12.2               -17.6           64               22             24.1           100.88   Mainly Clear
# 2013-01-01 12:00:00     -11.8               -17.2           64               26             24.1           100.87   Mainly Clear
# 2013-01-01 13:00:00     -11.3               -17.4           61               26             24.1           100.83   Mainly Clear
# 2013-01-01 14:00:00     -11.3               -17.4           61               28             24.1           100.82   Mainly Clear
# 2013-01-01 15:00:00     -11.4               -17.6           60               30             24.1           100.85   Mainly Clear
# 2013-01-01 16:00:00     -12.0               -18.0           61               22             24.1           100.81   Mainly Clear
# 2013-01-01 17:00:00     -13.0               -18.4           64               19             25.0           100.90          Clear
# 2013-01-01 18:00:00     -13.4               -18.4           66               24             25.0           100.96          Clear
# 2013-01-01 19:00:00     -14.1               -18.7           68               20             25.0           101.02          Clear
# 2013-01-01 20:00:00     -14.3               -19.0           67               15             25.0           101.04          Clear
# 2013-01-01 21:00:00     -14.8               -19.5           67               15             25.0           100.98   Mainly Clear
# 2013-01-01 22:00:00     -16.3               -20.2           72                7             25.0           100.98  Mostly Cloudy
# 2013-01-01 23:00:00     -15.4               -19.8           69               11             25.0           100.99         Cloudy
# 2013-01-02 00:00:00     -14.0               -18.4           69               11             19.3           100.96           Snow
# 2013-01-02 01:00:00     -14.1               -18.3           70               11             25.0           100.91  Mostly Cloudy
# 2013-01-02 02:00:00     -14.3               -18.3           72               13             25.0           100.94   Snow Showers
# 2013-01-02 03:00:00     -14.7               -18.0           76                9             19.3           100.91           Snow
# 2013-01-02 04:00:00     -14.2               -17.1           79                6              9.7           100.83           Snow
# 2013-01-02 05:00:00     -14.3               -17.0           80                0              6.4           100.81           Snow
# ...                       ...                 ...          ...              ...              ...              ...            ...
# 2012-12-30 18:00:00     -12.6               -16.0           76               24             25.0           101.36   Mainly Clear
# 2012-12-30 19:00:00     -13.4               -16.5           77               26             25.0           101.47   Mainly Clear
# 2012-12-30 20:00:00     -13.8               -16.5           80               24             25.0           101.52          Clear
# 2012-12-30 21:00:00     -13.8               -16.5           80               20             25.0           101.50   Mainly Clear
# 2012-12-30 22:00:00     -13.7               -16.3           81               19             25.0           101.54   Mainly Clear
# 2012-12-30 23:00:00     -12.1               -15.1           78               28             25.0           101.52  Mostly Cloudy
# 2012-12-31 00:00:00     -11.1               -14.4           77               26             25.0           101.51         Cloudy
# 2012-12-31 01:00:00     -10.7               -14.0           77               15             25.0           101.50         Cloudy
# 2012-12-31 02:00:00     -10.1               -13.4           77                9             25.0           101.45         Cloudy
# 2012-12-31 03:00:00     -11.8               -14.4           81                6             25.0           101.42  Mostly Cloudy
# 2012-12-31 04:00:00     -10.5               -12.8           83               11             25.0           101.34         Cloudy
# 2012-12-31 05:00:00     -10.2               -12.4           84                6             25.0           101.28         Cloudy
# 2012-12-31 06:00:00      -9.7               -11.7           85                4             25.0           101.23         Cloudy
# 2012-12-31 07:00:00      -9.3               -11.3           85                0             19.3           101.19   Snow Showers
# 2012-12-31 08:00:00      -8.6               -10.3           87                4              3.2           101.14   Snow Showers
# 2012-12-31 09:00:00      -8.1                -9.6           89                4              2.4           101.09           Snow
# 2012-12-31 10:00:00      -7.4                -8.9           89                4              6.4           101.05       Snow,Fog
# 2012-12-31 11:00:00      -6.7                -7.9           91                9              9.7           100.93           Snow
# 2012-12-31 12:00:00      -5.8                -7.5           88                4             12.9           100.78           Snow
# 2012-12-31 13:00:00      -4.6                -6.6           86                4             12.9           100.63           Snow
# 2012-12-31 14:00:00      -3.4                -5.7           84                6             11.3           100.57           Snow
# 2012-12-31 15:00:00      -2.3                -4.6           84                9              9.7           100.47           Snow
# 2012-12-31 16:00:00      -1.4                -4.0           82               13             12.9           100.40           Snow
# 2012-12-31 17:00:00      -1.1                -3.3           85               19              9.7           100.30           Snow
# 2012-12-31 18:00:00      -1.3                -3.1           88               17              9.7           100.19           Snow
# 2012-12-31 19:00:00       0.1                -2.7           81               30              9.7           100.13           Snow
# 2012-12-31 20:00:00       0.2                -2.4           83               24              9.7           100.03           Snow
# 2012-12-31 21:00:00      -0.5                -1.5           93               28              4.8            99.95           Snow
# 2012-12-31 22:00:00      -0.2                -1.8           89               28              9.7            99.91           Snow
# 2012-12-31 23:00:00       0.0                -2.1           86               30             11.3            99.89           Snow
#
# [8784 rows x 7 columns]

# %%
weather_2012.to_csv('../data/weather_2012.csv')

# %%
# The usual preamble
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Make the graphs a bit prettier, and bigger
pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 5)

# This is necessary to show lots of columns in pandas 0.12. 
# Not necessary in pandas 0.13.
pd.set_option('display.line_width', 5000) 
pd.set_option('display.max_columns', 60)
# Out:
# line_width has been deprecated, use display.width instead (currently both are
# identical)

# %%
requests = pd.read_csv('../data/311-service-requests.csv')
# Out:
# c:\Users\marcelo.galdos\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:1139: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
requests['Incident Zip'].unique()
# Out:
# array([11432.0, 11378.0, 10032.0, 10023.0, 10027.0, 11372.0, 11419.0,
#        11417.0, 10011.0, 11225.0, 11218.0, 10003.0, 10029.0, 10466.0,
#        11219.0, 10025.0, 10310.0, 11236.0, nan, 10033.0, 11216.0, 10016.0,
#        10305.0, 10312.0, 10026.0, 10309.0, 10036.0, 11433.0, 11235.0,
#        11213.0, 11379.0, 11101.0, 10014.0, 11231.0, 11234.0, 10457.0,
#        10459.0, 10465.0, 11207.0, 10002.0, 10034.0, 11233.0, 10453.0,
#        10456.0, 10469.0, 11374.0, 11221.0, 11421.0, 11215.0, 10007.0,
#        10019.0, 11205.0, 11418.0, 11369.0, 11249.0, 10005.0, 10009.0,
#        11211.0, 11412.0, 10458.0, 11229.0, 10065.0, 10030.0, 11222.0,
#        10024.0, 10013.0, 11420.0, 11365.0, 10012.0, 11214.0, 11212.0,
#        10022.0, 11232.0, 11040.0, 11226.0, 10281.0, 11102.0, 11208.0,
#        10001.0, 10472.0, 11414.0, 11223.0, 10040.0, 11220.0, 11373.0,
#        11203.0, 11691.0, 11356.0, 10017.0, 10452.0, 10280.0, 11217.0,
#        10031.0, 11201.0, 11358.0, 10128.0, 11423.0, 10039.0, 10010.0,
#        11209.0, 10021.0, 10037.0, 11413.0, 11375.0, 11238.0, 10473.0,
#        11103.0, 11354.0, 11361.0, 11106.0, 11385.0, 10463.0, 10467.0,
#        11204.0, 11237.0, 11377.0, 11364.0, 11434.0, 11435.0, 11210.0,
#        11228.0, 11368.0, 11694.0, 10464.0, 11415.0, 10314.0, 10301.0,
#        10018.0, 10038.0, 11105.0, 11230.0, 10468.0, 11104.0, 10471.0,
#        11416.0, 10075.0, 11422.0, 11355.0, 10028.0, 10462.0, 10306.0,
#        10461.0, 11224.0, 11429.0, 10035.0, 11366.0, 11362.0, 11206.0,
#        10460.0, 10304.0, 11360.0, 11411.0, 10455.0, 10475.0, 10069.0,
#        10303.0, 10308.0, 10302.0, 11357.0, 10470.0, 11367.0, 11370.0,
#        10454.0, 10451.0, 11436.0, 11426.0, 10153.0, 11004.0, 11428.0,
#        11427.0, 11001.0, 11363.0, 10004.0, 10474.0, 11430.0, 10000.0,
#        10307.0, 11239.0, 10119.0, 10006.0, 10048.0, 11697.0, 11692.0,
#        11693.0, 10573.0, 83.0, 11559.0, 10020.0, 77056.0, 11776.0, 70711.0,
#        10282.0, 11109.0, 10044.0, '10452', '11233', '10468', '10310',
#        '11105', '10462', '10029', '10301', '10457', '10467', '10469',
#        '11225', '10035', '10031', '11226', '10454', '11221', '10025',
#        '11229', '11235', '11422', '10472', '11208', '11102', '10032',
#        '11216', '10473', '10463', '11213', '10040', '10302', '11231',
#        '10470', '11204', '11104', '11212', '10466', '11416', '11214',
#        '10009', '11692', '11385', '11423', '11201', '10024', '11435',
#        '10312', '10030', '11106', '10033', '10303', '11215', '11222',
#        '11354', '10016', '10034', '11420', '10304', '10019', '11237',
#        '11249', '11230', '11372', '11207', '11378', '11419', '11361',
#        '10011', '11357', '10012', '11358', '10003', '10002', '11374',
#        '10007', '11234', '10065', '11369', '11434', '11205', '11206',
#        '11415', '11236', '11218', '11413', '10458', '11101', '10306',
#        '11355', '10023', '11368', '10314', '11421', '10010', '10018',
#        '11223', '10455', '11377', '11433', '11375', '10037', '11209',
#        '10459', '10128', '10014', '10282', '11373', '10451', '11238',
#        '11211', '10038', '11694', '11203', '11691', '11232', '10305',
#        '10021', '11228', '10036', '10001', '10017', '11217', '11219',
#        '10308', '10465', '11379', '11414', '10460', '11417', '11220',
#        '11366', '10027', '11370', '10309', '11412', '11356', '10456',
#        '11432', '10022', '10013', '11367', '11040', '10026', '10475',
#        '11210', '11364', '11426', '10471', '10119', '11224', '11418',
#        '11429', '11365', '10461', '11239', '10039', '00083', '11411',
#        '10075', '11004', '11360', '10453', '10028', '11430', '10307',
#        '11103', '10004', '10069', '10005', '10474', '11428', '11436',
#        '10020', '11001', '11362', '11693', '10464', '11427', '10044',
#        '11363', '10006', '10000', '02061', '77092-2016', '10280', '11109',
#        '14225', '55164-0737', '19711', '07306', '000000', 'NO CLUE',
#        '90010', '10281', '11747', '23541', '11776', '11697', '11788',
#        '07604', 10112.0, 11788.0, 11563.0, 11580.0, 7087.0, 11042.0,
#        7093.0, 11501.0, 92123.0, 0.0, 11575.0, 7109.0, 11797.0, '10803',
#        '11716', '11722', '11549-3650', '10162', '92123', '23502', '11518',
#        '07020', '08807', '11577', '07114', '11003', '07201', '11563',
#        '61702', '10103', '29616-0759', '35209-3114', '11520', '11735',
#        '10129', '11005', '41042', '11590', 6901.0, 7208.0, 11530.0,
#        13221.0, 10954.0, 11735.0, 10103.0, 7114.0, 11111.0, 10107.0], dtype=object)

# %%
na_values = ['NO CLUE', 'N/A', '0']
requests = pd.read_csv('../data/311-service-requests.csv', na_values=na_values, dtype={'Incident Zip': str})
requests['Incident Zip'].unique()
# Out:
# array(['11432', '11378', '10032', '10023', '10027', '11372', '11419',
#        '11417', '10011', '11225', '11218', '10003', '10029', '10466',
#        '11219', '10025', '10310', '11236', nan, '10033', '11216', '10016',
#        '10305', '10312', '10026', '10309', '10036', '11433', '11235',
#        '11213', '11379', '11101', '10014', '11231', '11234', '10457',
#        '10459', '10465', '11207', '10002', '10034', '11233', '10453',
#        '10456', '10469', '11374', '11221', '11421', '11215', '10007',
#        '10019', '11205', '11418', '11369', '11249', '10005', '10009',
#        '11211', '11412', '10458', '11229', '10065', '10030', '11222',
#        '10024', '10013', '11420', '11365', '10012', '11214', '11212',
#        '10022', '11232', '11040', '11226', '10281', '11102', '11208',
#        '10001', '10472', '11414', '11223', '10040', '11220', '11373',
#        '11203', '11691', '11356', '10017', '10452', '10280', '11217',
#        '10031', '11201', '11358', '10128', '11423', '10039', '10010',
#        '11209', '10021', '10037', '11413', '11375', '11238', '10473',
#        '11103', '11354', '11361', '11106', '11385', '10463', '10467',
#        '11204', '11237', '11377', '11364', '11434', '11435', '11210',
#        '11228', '11368', '11694', '10464', '11415', '10314', '10301',
#        '10018', '10038', '11105', '11230', '10468', '11104', '10471',
#        '11416', '10075', '11422', '11355', '10028', '10462', '10306',
#        '10461', '11224', '11429', '10035', '11366', '11362', '11206',
#        '10460', '10304', '11360', '11411', '10455', '10475', '10069',
#        '10303', '10308', '10302', '11357', '10470', '11367', '11370',
#        '10454', '10451', '11436', '11426', '10153', '11004', '11428',
#        '11427', '11001', '11363', '10004', '10474', '11430', '10000',
#        '10307', '11239', '10119', '10006', '10048', '11697', '11692',
#        '11693', '10573', '00083', '11559', '10020', '77056', '11776',
#        '70711', '10282', '11109', '10044', '02061', '77092-2016', '14225',
#        '55164-0737', '19711', '07306', '000000', '90010', '11747', '23541',
#        '11788', '07604', '10112', '11563', '11580', '07087', '11042',
#        '07093', '11501', '92123', '00000', '11575', '07109', '11797',
#        '10803', '11716', '11722', '11549-3650', '10162', '23502', '11518',
#        '07020', '08807', '11577', '07114', '11003', '07201', '61702',
#        '10103', '29616-0759', '35209-3114', '11520', '11735', '10129',
#        '11005', '41042', '11590', '06901', '07208', '11530', '13221',
#        '10954', '11111', '10107'], dtype=object)

# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect()
