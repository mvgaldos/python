# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.set_option('display.mpl_style', 'default')
plt.rcParams['figure.figsize'] = (15, 3)

# %%
c_stock = pd.read_csv('C:/temp/c_stock_mg.csv')

# %%
list(c_stock)
# Out:
# ['ID_PAIR',
#  'ID_SITE',
#  'ID_Field',
#  'City',
#  'Land Use',
#  'Age',
#  'Years without burning',
#  'Top',
#  'Bottom',
#  'Bulk_Density_Average',
#  'C_Average',
#  'Stck_C_Average',
#  'Sand',
#  'Clay',
#  'Silt']

# %%
c_stock['Silt'].unique() #look at each parameter to check it
# Out:
# array([  8.29000000e+00,   1.04300000e+01,   1.01400000e+01,
#          8.58000000e+00,   7.01000000e+00,   8.55000000e+00,
#          9.33000000e+00,   1.01000000e+01,   7.79000000e+00,
#          5.48000000e+00,   8.30000000e+00,   1.04000000e+01,
#          8.60000000e+00,   7.00000000e+00,   9.30000000e+00,
#          7.80000000e+00,   5.50000000e+00,   7.04000000e+00,
#          6.39000000e+00,   9.72000000e+00,   8.46000000e+00,
#          7.21000000e+00,   7.90000000e+00,   8.25000000e+00,
#          7.20000000e+00,   9.70000000e+00,   6.80000000e+00,
#          8.00000000e+00,   9.10000000e+00,   6.50000000e+00,
#          5.33000000e+00,   6.27000000e+00,   5.68000000e+00,
#          5.45000000e+00,   5.22000000e+00,   4.21000000e+00,
#          3.71000000e+00,   3.21000000e+00,   2.49000000e+00,
#          1.78000000e+00,   8.10000000e+00,   1.24000000e+01,
#          9.80000000e+00,   7.30000000e+00,   5.60000000e+00,
# ...

# %%
c_stock
# Out:
#       ID_PAIR  ID_SITE ID_Field        City    Land Use  Age  \
# 0          16       27      NaN   Andradina   Sugarcane    5
# 1          16       27      NaN   Andradina  Sugarcane     5
# 2          16       27      NaN   Andradina   Sugarcane    5
# 3          16       27      NaN   Andradina   Sugarcane    5
# 4          16       27      NaN   Andradina  Sugarcane     5
# 5          16       27      NaN   Andradina   Sugarcane    5
# 6          16       27      NaN   Andradina   Sugarcane    5
# 7          16       27      NaN   Andradina  Sugarcane     5
# 8          16       27      NaN   Andradina   Sugarcane    5
# 9          16       27      NaN   Andradina   Sugarcane    5
# 10         16       28      NaN   Andradina     Pasture  NaN
# 11         16       28      NaN   Andradina     Pasture  NaN
# 12         16       28      NaN   Andradina     Pasture  NaN
# 13         16       28      NaN   Andradina     Pasture  NaN
# ...

# %%
latlongChico = pd.read_csv('C:/temp/latlongChico.csv')
latlongChico
# Out:
#      ID_SITE   Municipio   UF          Y          X ID_Campo
# 0         35   Andradina   SP -20.822500 -51.287000   AD126C
# 1         36   Andradina   SP -20.821800 -51.287400   AD126P
# 2         27   Andradina   SP -20.703300 -51.256800   AD129C
# 3         28   Andradina   SP -20.703100 -51.256200   AD129P
# 4         31   Andradina   SP -20.857700 -51.288200    AD16C
# 5         32   Andradina   SP -20.857000 -51.287700    AD16P
# 6         29   Andradina   SP -20.805600 -51.302700   AD211C
# 7         30   Andradina   SP -20.805600 -51.302100   AD211P
# 8         33   Andradina   SP -20.727700 -51.245800    AD45C
# 9         34   Andradina   SP -20.727200 -51.246400    AD45P
# 10        16     Anhembi   SP -22.753800 -47.935500      AN1
# 11        25     Anhembi   SP -22.814700 -48.105900     AN10
# 12        26     Anhembi   SP -22.810800 -48.109600     AN11
# 13        17     Anhembi   SP -22.754400 -47.934700      AN2
# ...

# %%
chico = pd.merge(latlongChico, c_stock, on='ID_SITE')
chico
# Out:
#       ID_SITE   Municipio  UF          Y          X ID_Campo  ID_PAIR  \
# 0          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 1          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 2          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 3          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 4          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 5          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 6          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 7          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 8          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 9          35   Andradina  SP -20.822500 -51.287000   AD126C       79
# 10         36   Andradina  SP -20.821800 -51.287400   AD126P       79
# 11         36   Andradina  SP -20.821800 -51.287400   AD126P       79
# ...

# %%
supmat = pd.read_csv('C:/temp/latlongChico.csv')
